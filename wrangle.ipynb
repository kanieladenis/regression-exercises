# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Exercise 2
# ## Your goal is to predict the values of single unit properties using the obervations from 2017.
# ###

# %% [markdown]
# 1. Acquire bedroomcnt, bathroomcnt, calculatedfinishedsquarefeet, taxvaluedollarcnt, yearbuilt, taxamount, and fips from the zillow database for all 'Single Family Residential' properties.

# %%
import acquire_zillow

# %%
df = acquire_zillow.get_zillow()
df.head()
# Out:
#    bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  taxvaluedollarcnt  \
# 0         0.0          0.0                           NaN            27516.0
# 1         0.0          0.0                           NaN               10.0
# 2         0.0          0.0                           NaN               10.0
# 3         0.0          0.0                           NaN             2108.0
# 4         4.0          2.0                        3633.0           296425.0
#
#    yearbuilt  taxamount    fips
# 0        NaN        NaN  6037.0
# 1        NaN        NaN  6037.0
# 2        NaN        NaN  6037.0
# 3        NaN     174.21  6037.0
# 4     2005.0    6941.39  6037.0

# %%
df.isnull().sum()
# Out:
# bedroomcnt                        11
# bathroomcnt                       11
# calculatedfinishedsquarefeet    8484
# taxvaluedollarcnt                493
# yearbuilt                       9337
# taxamount                       4442
# fips                               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2152863 entries, 0 to 2152862
# Data columns (total 7 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   bedroomcnt                    float64
#  1   bathroomcnt                   float64
#  2   calculatedfinishedsquarefeet  float64
#  3   taxvaluedollarcnt             float64
#  4   yearbuilt                     float64
#  5   taxamount                     float64
#  6   fips                          float64
# dtypes: float64(7)
# memory usage: 115.0 MB

# %% [markdown]
# 2. Using your acquired Zillow data, walk through the summarization and cleaning steps in your wrangle.ipynb file like we did above. You may handle the missing values however you feel is appropriate and meaninful; remember to document your process and decisions using markdown and code commenting where helpful.

# %%
# see how many rows and columns
df.shape
# Out:
# (2152863, 7)

# %%
df.describe()
# Out:
#          bedroomcnt   bathroomcnt  calculatedfinishedsquarefeet  \
# count  2.152852e+06  2.152852e+06                  2.144379e+06
# mean   3.287196e+00  2.230688e+00                  1.862855e+03
# std    9.547544e-01  9.992796e-01                  1.222125e+03
# min    0.000000e+00  0.000000e+00                  1.000000e+00
# 25%    3.000000e+00  2.000000e+00                  1.257000e+03
# 50%    3.000000e+00  2.000000e+00                  1.623000e+03
# 75%    4.000000e+00  3.000000e+00                  2.208000e+03
# max    2.500000e+01  3.200000e+01                  9.525760e+05
#
#        taxvaluedollarcnt     yearbuilt     taxamount          fips
# count       2.152370e+06  2.143526e+06  2.148421e+06  2.152863e+06
# mean        4.618962e+05  1.960950e+03  5.634866e+03  6.048377e+03
# std         6.996760e+05  2.216220e+01  8.178910e+03  2.043329e+01
# min         1.000000e+00  1.801000e+03  1.850000e+00  6.037000e+03
# ...

# %%
# check if all columns show
df.describe().T
# Out:
#                                   count           mean            std  \
# bedroomcnt                    2152852.0       3.287196       0.954754
# bathroomcnt                   2152852.0       2.230688       0.999280
# calculatedfinishedsquarefeet  2144379.0    1862.855178    1222.125124
# taxvaluedollarcnt             2152370.0  461896.237963  699676.049600
# yearbuilt                     2143526.0    1960.949681      22.162196
# taxamount                     2148421.0    5634.865978    8178.910249
# fips                          2152863.0    6048.377335      20.433292
#
#                                   min        25%        50%        75%  \
# bedroomcnt                       0.00       3.00       3.00       4.00
# bathroomcnt                      0.00       2.00       2.00       3.00
# calculatedfinishedsquarefeet     1.00    1257.00    1623.00    2208.00
# taxvaluedollarcnt                1.00  188170.25  327671.00  534527.00
# ...

# %%
# find counts of nulls
df.isnull().sum()
# Out:
# bedroomcnt                        11
# bathroomcnt                       11
# calculatedfinishedsquarefeet    8484
# taxvaluedollarcnt                493
# yearbuilt                       9337
# taxamount                       4442
# fips                               0
# dtype: int64

# %%
# find columsn that have nulls
df.isnull().any()
# Out:
# bedroomcnt                       True
# bathroomcnt                      True
# calculatedfinishedsquarefeet     True
# taxvaluedollarcnt                True
# yearbuilt                        True
# taxamount                        True
# fips                            False
# dtype: bool

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['bedroomcnt', 'bathroomcnt', 'calculatedfinishedsquarefeet',
#        'taxvaluedollarcnt', 'yearbuilt', 'taxamount'],
#       dtype='object')

# %%
# show na in bedroom count column
df.bedroomcnt.value_counts(dropna=False, ascending=True)
# Out:
# 25.0         1
# 16.0         2
# 18.0         3
# 15.0         6
# 14.0         7
# NaN         11
# 12.0        12
# 13.0        16
# 11.0        34
# 10.0       121
# 9.0        291
# 8.0       1107
# 7.0       4807
# 0.0      13187
# 1.0      23166
# 6.0      25166
# 5.0     150866
# 2.0     335473
# 4.0     634289
# 3.0     964298
# Name: bedroomcnt, dtype: int64

# %%
df.bedroomcnt.value_counts()
# Out:
# 3.0     964298
# 4.0     634289
# 2.0     335473
# 5.0     150866
# 6.0      25166
# 1.0      23166
# 0.0      13187
# 7.0       4807
# 8.0       1107
# 9.0        291
# 10.0       121
# 11.0        34
# 13.0        16
# 12.0        12
# 14.0         7
# 15.0         6
# 18.0         3
# 16.0         2
# 25.0         1
# Name: bedroomcnt, dtype: int64

# %%
bedroomcnt = df[df.bedroomcnt.isnull()]
bedroomcnt
# Out:
#          bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 107763          NaN          NaN                           NaN
# 118612          NaN          NaN                           NaN
# 193993          NaN          NaN                        1348.0
# 1141339         NaN          NaN                         200.0
# 1324608         NaN          NaN                         990.0
# 1442975         NaN          NaN                           NaN
# 1647346         NaN          NaN                         400.0
# 1701026         NaN          NaN                           NaN
# 1722707         NaN          NaN                           NaN
# 1776422         NaN          NaN                           NaN
# 1797985         NaN          NaN                           NaN
#
#          taxvaluedollarcnt  yearbuilt  taxamount    fips
# 107763             67366.0     1926.0     780.54  6059.0
# 118612             43992.0     1946.0     541.64  6059.0
# ...

# %%
bathroomcnt = df[df.bathroomcnt.isnull()]
bathroomcnt
# Out:
#          bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 107763          NaN          NaN                           NaN
# 118612          NaN          NaN                           NaN
# 193993          NaN          NaN                        1348.0
# 1141339         NaN          NaN                         200.0
# 1324608         NaN          NaN                         990.0
# 1442975         NaN          NaN                           NaN
# 1647346         NaN          NaN                         400.0
# 1701026         NaN          NaN                           NaN
# 1722707         NaN          NaN                           NaN
# 1776422         NaN          NaN                           NaN
# 1797985         NaN          NaN                           NaN
#
#          taxvaluedollarcnt  yearbuilt  taxamount    fips
# 107763             67366.0     1926.0     780.54  6059.0
# 118612             43992.0     1946.0     541.64  6059.0
# ...

# %%
calculatedfinishedsquarefeet = df[df.calculatedfinishedsquarefeet.isnull()]
calculatedfinishedsquarefeet
# Out:
#          bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 0               0.0          0.0                           NaN
# 1               0.0          0.0                           NaN
# 2               0.0          0.0                           NaN
# 3               0.0          0.0                           NaN
# 5               0.0          0.0                           NaN
# ...             ...          ...                           ...
# 2152823         0.0          0.0                           NaN
# 2152844         0.0          0.0                           NaN
# 2152854         0.0          0.0                           NaN
# 2152857         0.0          0.0                           NaN
# 2152860         0.0          0.0                           NaN
#
#          taxvaluedollarcnt  yearbuilt  taxamount    fips
# 0                  27516.0        NaN        NaN  6037.0
# 1                     10.0        NaN        NaN  6037.0
# ...

# %%
taxvaluedollarcnt = df[df.taxvaluedollarcnt.isnull()]
taxvaluedollarcnt
# Out:
#          bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 10694           0.0          0.0                           NaN
# 10779           0.0          0.0                           NaN
# 26588           3.0          1.0                         807.0
# 32251           0.0          0.0                           NaN
# 32656           2.0          2.0                        1650.0
# ...             ...          ...                           ...
# 2131494         0.0          0.0                           NaN
# 2142029         0.0          0.0                           NaN
# 2142113         3.0          2.0                        1432.0
# 2142169         0.0          0.0                           NaN
# 2142173         0.0          0.0                           NaN
#
#          taxvaluedollarcnt  yearbuilt  taxamount    fips
# 10694                  NaN        NaN        NaN  6111.0
# 10779                  NaN        NaN        NaN  6111.0
# ...

# %%
yearbuilt = df[df.yearbuilt.isnull()]
yearbuilt
# Out:
#          bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 0               0.0          0.0                           NaN
# 1               0.0          0.0                           NaN
# 2               0.0          0.0                           NaN
# 3               0.0          0.0                           NaN
# 5               0.0          0.0                           NaN
# ...             ...          ...                           ...
# 2152823         0.0          0.0                           NaN
# 2152844         0.0          0.0                           NaN
# 2152854         0.0          0.0                           NaN
# 2152857         0.0          0.0                           NaN
# 2152860         0.0          0.0                           NaN
#
#          taxvaluedollarcnt  yearbuilt  taxamount    fips
# 0                  27516.0        NaN        NaN  6037.0
# 1                     10.0        NaN        NaN  6037.0
# ...

# %%
taxamount = df[df.taxamount.isnull()]
taxamount
# Out:
#          bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 0               0.0          0.0                           NaN
# 1               0.0          0.0                           NaN
# 2               0.0          0.0                           NaN
# 5               0.0          0.0                           NaN
# 10              0.0          0.0                           NaN
# ...             ...          ...                           ...
# 2149353         0.0          0.0                         324.0
# 2151358         2.0          1.5                        1482.0
# 2152488         3.0          2.0                         992.0
# 2152503         3.0          1.0                        1894.0
# 2152854         0.0          0.0                           NaN
#
#          taxvaluedollarcnt  yearbuilt  taxamount    fips
# 0                  27516.0        NaN        NaN  6037.0
# 1                     10.0        NaN        NaN  6037.0
# ...

# %%
cols = ['bedroomcnt', 'bathroomcnt', 'calculatedfinishedsquarefeet',
       'taxvaluedollarcnt', 'yearbuilt', 'taxamount']
for col in cols:
    print(f'-------Column: {col}--------------')
    df_new = df[df[col].isnull()]
    print(f'Rows:Columns = {df_new.shape}')
    print(df_new)
# Out:
# -----------bedroomcnt--------------
# Rows:Columns = (11, 7)
#          bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  \
# 107763          NaN          NaN                           NaN
# 118612          NaN          NaN                           NaN
# 193993          NaN          NaN                        1348.0
# 1141339         NaN          NaN                         200.0
# 1324608         NaN          NaN                         990.0
# 1442975         NaN          NaN                           NaN
# 1647346         NaN          NaN                         400.0
# 1701026         NaN          NaN                           NaN
# 1722707         NaN          NaN                           NaN
# 1776422         NaN          NaN                           NaN
# 1797985         NaN          NaN                           NaN
#
#          taxvaluedollarcnt  yearbuilt  taxamount    fips
# 107763             67366.0     1926.0     780.54  6059.0
# ...

# %%
plt.figure(figsize=(16, 3))

# List of columns
cols = [col for col in df.columns if col not in ['fips', 'year_built']]

for i, col in enumerate(cols):

    # i starts at 0, but plot nos should start at 1
    plot_number = i + 1 

    # Create subplot.
    plt.subplot(1, len(cols), plot_number)

    # Title with column name.
    plt.title(col)

    # Display histogram for column.
    df[col].hist(bins=5)

    # Hide gridlines.
    plt.grid(False)
    
    # turn off scientific notation
    plt.ticklabel_format(useOffset=False)

# %%
# Look at the blox plot distribution
# List of columns
cols = [col for col in df.columns if col not in ['fips', 'yearbuilt']]
plt.figure(figsize=(16, 20))
for i, col in enumerate(cols):

    # i starts at 0, but plot nos should start at 1
    plot_number = i + 1 

    # Create subplot.
    plt.subplot(1, len(cols), plot_number)

    # Title with column name.
    plt.title(col)

    # Display boxplot for column.
    sns.boxplot(data=df[col])

    # Hide gridlines.
    plt.grid(False)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-acd5e049b0a0> in <module>
#      15
#      16     # Display boxplot for column.
# ---> 17     sns.boxplot(data=df[col])
#      18
#      19     # Hide gridlines.
#
# ...

# %%
df = df.dropna()

# %%
df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2140235 entries, 4 to 2152862
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   bedroomcnt                    2140235 non-null  float64
#  1   bathroomcnt                   2140235 non-null  float64
#  2   calculatedfinishedsquarefeet  2140235 non-null  float64
#  3   taxvaluedollarcnt             2140235 non-null  float64
#  4   yearbuilt                     2140235 non-null  float64
#  5   taxamount                     2140235 non-null  float64
#  6   fips                          2140235 non-null  float64
# dtypes: float64(7)
# memory usage: 130.6 MB

# %%
df.isna().sum()
# Out:
# bedroomcnt                      0
# bathroomcnt                     0
# calculatedfinishedsquarefeet    0
# taxvaluedollarcnt               0
# yearbuilt                       0
# taxamount                       0
# fips                            0
# dtype: int64

# %%
plt.figure(figsize=(16, 3))

# List of columns
cols = [col for col in df.columns if col not in ['fips', 'yearbuilt']]

for i, col in enumerate(cols):

    # i starts at 0, but plot nos should start at 1
    plot_number = i + 1 

    # Create subplot.
    plt.subplot(1, len(cols), plot_number)

    # Title with column name.
    plt.title(col)

    # Display histogram for column.
    df[col].hist(bins=5)

    # Hide gridlines.
    plt.grid(False)
    
    # turn off scientific notation
    plt.ticklabel_format(useOffset=False)

# %%
df.columns.[features]
# Out:
#   File "<ipython-input-65-1604c1d7ee21>", line 1
#     df.columns.[features]
#                ^
# SyntaxError: invalid syntax

# %%
col_list =['bedroomcnt',
 'bathroomcnt',
 'calculatedfinishedsquarefeet',
 'taxvaluedollarcnt',
 'yearbuilt',
 'taxamount']

for col in col_list:

        q1, q3 = df[col].quantile([.25, .75])  # get quartiles
        
        iqr = q3 - q1   # calculate interquartile range
        
        upper_bound = q3 + k * iqr   # get upper bound
        lower_bound = q1 - k * iqr   # get lower bound

        # return dataframe without outliers
        
        df = df[(df[col] > lower_bound) & (df[col] < upper_bound)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-be6038b826ca> in <module>
#      12         iqr = q3 - q1   # calculate interquartile range
#      13
# ---> 14         upper_bound = q3 + k * iqr   # get upper bound
#      15         lower_bound = q1 - k * iqr   # get lower bound
#      16
#
# NameError: name 'k' is not defined

# %% [markdown]
# 3. Store all of the necessary functions to automate your process from acquiring the data to returning a cleaned dataframe witn no missing values in your wrangle.py file. Name your final function wrangle_zillow.
